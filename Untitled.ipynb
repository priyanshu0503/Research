# %%
pkg> add https://github.com/mlesnoff/JchemoData.jl.git
# Out:
#   File "/tmp/ipykernel_599995/3878817571.py", line 1
#     pkg> add https://github.com/mlesnoff/JchemoData.jl.git
#              ^
# SyntaxError: invalid syntax
